# %% [markdown]
# <a href="https://colab.research.google.com/github/CivitCihan/DataVirtualization/blob/main/DataVirtualization6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Data Analysis and Virtualization with Time Series Graph</h1>

# %%
import yfinance as yf

df = yf.download("TSLA", start = "2024-01-01", end = "2025-02-01")
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2024-01-02  248.419998  251.250000  244.410004  250.080002  104654200
# 2024-01-03  238.449997  245.679993  236.320007  244.979996  121082600
# 2024-01-04  237.929993  242.699997  237.729996  239.250000  102629300
# 2024-01-05  237.490005  240.119995  234.899994  236.860001   92379400
# 2024-01-08  240.449997  241.250000  235.300003  236.139999   85166600

# %%
close = df['Close']
close.head()
# Out:
# Ticker            TSLA
# Date
# 2024-01-02  248.419998
# 2024-01-03  238.449997
# 2024-01-04  237.929993
# 2024-01-05  237.490005
# 2024-01-08  240.449997

# %%
close.plot()
# Out:
# <Axes: xlabel='Date'>
